# %%
import torch
import json
import os
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import optuna
from torchsummary import summary

# %%
# CPUスレッド数を設定
torch.set_num_threads(4)  # 使用するスレッド数を4に設定

# %%
class CustomDataset(Dataset):
    def __init__(self, json_path):
        with open(json_path, 'r') as f:
            data = json.load(f)
        self.inputs = data["inputs"]
        self.outputs = data["outputs"]

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        x = torch.tensor(self.inputs[idx], dtype=torch.float32)
        y = torch.tensor(self.outputs[idx], dtype=torch.float32)
        return x, y

def get_dataloader(json_path, batch_size=16):
    dataset = CustomDataset(json_path)
    return DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
class SimpleModel(nn.Module):
    def __init__(self, input_dim=3, output_dim=2):
        super(SimpleModel, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )

    def forward(self, x):
        return self.network(x)

# %%
# モデルのサマリーを表示
summary(SimpleModel(), (1, 3))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]             256
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3               [-1, 1, 128]           8,320
#               ReLU-4               [-1, 1, 128]               0
#             Linear-5               [-1, 1, 256]          33,024
#               ReLU-6               [-1, 1, 256]               0
#             Linear-7               [-1, 1, 512]         131,584
#               ReLU-8               [-1, 1, 512]               0
#             Linear-9              [-1, 1, 1024]         525,312
#              ReLU-10              [-1, 1, 1024]               0
#           Dropout-11              [-1, 1, 1024]               0
#            Linear-12               [-1, 1, 256]         262,400
#              ReLU-13               [-1, 1, 256]               0
#            Linear-14               [-1, 1, 128]          32,896
#              ReLU-15               [-1, 1, 128]               0
#            Linear-16                 [-1, 1, 2]             258
# ================================================================
# Total params: 994,050
# Trainable params: 994,050
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 3.79
# Estimated Total Size (MB): 3.84
# ----------------------------------------------------------------

# %%
def train_model(trial):
    # ベイズ最適化でハイパーパラメータを探索
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
    batch_size = trial.suggest_int('batch_size', 8, 64)
    
    model = SimpleModel()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    dataloader = get_dataloader('../data/data.json', batch_size=batch_size)

    model.train()
    best_loss = float('inf')  # 最良の損失値を保持する変数
    best_model = None  # 最良モデルを保持する変数

    num_epochs = 10  # エポック数
    progress_bar = tqdm(range(num_epochs), desc="Training Progress", unit="epoch")  # プログレスバーの初期化
    for epoch in progress_bar:
        epoch_loss = 0
        for x, y in dataloader:
            optimizer.zero_grad()
            y_pred = model(x)
            loss = criterion(y_pred, y)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        # 各エポック終了後に損失を計算し、最良のモデルを保存
        avg_loss = epoch_loss / len(dataloader)
        if avg_loss < best_loss:  # 最良の損失を更新
            best_loss = avg_loss
            best_model = model.state_dict()  # 最良モデルのパラメータを保存

        # プログレスバーに損失値をリアルタイム表示
        progress_bar.set_description(f"Epoch {epoch+1} | Loss: {avg_loss:.6f}")

    # 最良のモデルを保存
    if not os.path.exists('results'):
        os.makedirs('results')
    torch.save(best_model, 'results/best_model.pth')

    return best_loss  # 最良損失を返す


# Optunaのベイズ最適化
if __name__ == '__main__':
    study = optuna.create_study(direction='minimize')
    study.optimize(train_model, n_trials=100)
    print(f"Best params: {study.best_params}")
    print(f"Best loss: {study.best_value}")
# Out:
# [I 2024-11-24 10:12:14,354] A new study created in memory with name: no-name-96599b3b-e7e3-4cf1-874d-e2307df34b44
# /var/folders/gj/4tb33ww155x9v49s74kyhlcc0000gn/T/ipykernel_29197/2780606731.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# Epoch 10 | Loss: 10249342.000000: 100%|██████████| 10/10 [00:00<00:00, 221.58epoch/s]
# [I 2024-11-24 10:12:14,415] Trial 0 finished with value: 10249342.0 and parameters: {'lr': 0.00018754609684111252, 'batch_size': 34}. Best is trial 0 with value: 10249342.0.
# Epoch 10 | Loss: 10234944.000000: 100%|██████████| 10/10 [00:00<00:00, 252.93epoch/s]
# [I 2024-11-24 10:12:14,464] Trial 1 finished with value: 10234944.0 and parameters: {'lr': 0.0003962497954098932, 'batch_size': 60}. Best is trial 1 with value: 10234944.0.
# Epoch 10 | Loss: 10250642.000000: 100%|██████████| 10/10 [00:00<00:00, 266.12epoch/s]
# [I 2024-11-24 10:12:14,510] Trial 2 finished with value: 10250642.0 and parameters: {'lr': 0.00018052761710670408, 'batch_size': 58}. Best is trial 1 with value: 10234944.0.
# Epoch 10 | Loss: 9825971.750000: 100%|██████████| 10/10 [00:00<00:00, 157.01epoch/s]
# [I 2024-11-24 10:12:14,585] Trial 3 finished with value: 9717251.0 and parameters: {'lr': 0.0006389571416402796, 'batch_size': 16}. Best is trial 3 with value: 9717251.0.
# Epoch 10 | Loss: 10245023.000000: 100%|██████████| 10/10 [00:00<00:00, 241.84epoch/s]
# [I 2024-11-24 10:12:14,635] Trial 4 finished with value: 10245023.0 and parameters: {'lr': 0.00027841493107261895, 'batch_size': 57}. Best is trial 3 with value: 9717251.0.
# Epoch 10 | Loss: 11452996.250000: 100%|██████████| 10/10 [00:00<00:00, 158.98epoch/s]
# [I 2024-11-24 10:12:14,708] Trial 5 finished with value: 9799679.5 and parameters: {'lr': 0.0003544792251879179, 'batch_size': 19}. Best is trial 3 with value: 9717251.0.
# Epoch 10 | Loss: 11487044.000000: 100%|██████████| 10/10 [00:00<00:00, 169.02epoch/s]
# [I 2024-11-24 10:12:14,776] Trial 6 finished with value: 7728069.0 and parameters: {'lr': 0.005547300745145119, 'batch_size': 26}. Best is trial 6 with value: 7728069.0.
# Epoch 10 | Loss: 9106609.000000: 100%|██████████| 10/10 [00:00<00:00, 227.08epoch/s]
# [I 2024-11-24 10:12:14,833] Trial 7 finished with value: 9042654.0 and parameters: {'lr': 0.0027458358300749158, 'batch_size': 46}. Best is trial 6 with value: 7728069.0.
# Epoch 10 | Loss: 9303675.500000: 100%|██████████| 10/10 [00:00<00:00, 114.14epoch/s]
# [I 2024-11-24 10:12:14,931] Trial 8 finished with value: 9240491.5 and parameters: {'lr': 0.0015803434995932814, 'batch_size': 15}. Best is trial 6 with value: 7728069.0.
# Epoch 10 | Loss: 7602129.750000: 100%|██████████| 10/10 [00:00<00:00, 129.61epoch/s]
# [I 2024-11-24 10:12:15,019] Trial 9 finished with value: 7594020.25 and parameters: {'lr': 0.0026921524218908553, 'batch_size': 23}. Best is trial 9 with value: 7594020.25.
# Epoch 10 | Loss: 38660252.000000: 100%|██████████| 10/10 [00:00<00:00, 221.26epoch/s]
# [I 2024-11-24 10:12:15,082] Trial 10 finished with value: 10253363.0 and parameters: {'lr': 0.0804144380111816, 'batch_size': 38}. Best is trial 9 with value: 7594020.25.
# Epoch 10 | Loss: 7263871.500000: 100%|██████████| 10/10 [00:00<00:00, 138.93epoch/s]
# [I 2024-11-24 10:12:15,176] Trial 11 finished with value: 6413375.375 and parameters: {'lr': 0.010645329251931226, 'batch_size': 27}. Best is trial 11 with value: 6413375.375.
# Epoch 10 | Loss: 6498103.250000: 100%|██████████| 10/10 [00:00<00:00, 93.19epoch/s]
# [I 2024-11-24 10:12:15,297] Trial 12 finished with value: 5311400.226318359 and parameters: {'lr': 1.1998820715239497e-05, 'batch_size': 28}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 9074798.875000: 100%|██████████| 10/10 [00:00<00:00, 80.68epoch/s]
# [I 2024-11-24 10:12:15,435] Trial 13 finished with value: 8674825.375 and parameters: {'lr': 1.9640393040167766e-05, 'batch_size': 9}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 11160971.000000: 100%|██████████| 10/10 [00:00<00:00, 219.04epoch/s]
# [I 2024-11-24 10:12:15,494] Trial 14 finished with value: 9726590.0 and parameters: {'lr': 0.020302294040795296, 'batch_size': 33}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10253249.000000: 100%|██████████| 10/10 [00:00<00:00, 243.18epoch/s]
# [I 2024-11-24 10:12:15,551] Trial 15 finished with value: 10253249.0 and parameters: {'lr': 1.2413415655108798e-05, 'batch_size': 42}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10252544.000000: 100%|██████████| 10/10 [00:00<00:00, 224.31epoch/s]
# [I 2024-11-24 10:12:15,610] Trial 16 finished with value: 10252544.0 and parameters: {'lr': 6.375026253315086e-05, 'batch_size': 29}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10248885.000000: 100%|██████████| 10/10 [00:00<00:00, 213.01epoch/s]
# [I 2024-11-24 10:12:15,670] Trial 17 finished with value: 10022830.0 and parameters: {'lr': 0.010338357645604545, 'batch_size': 47}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 7014367.468750: 100%|██████████| 10/10 [00:00<00:00, 69.46epoch/s]
# [I 2024-11-24 10:12:15,828] Trial 18 finished with value: 7014367.46875 and parameters: {'lr': 0.029205158582685818, 'batch_size': 8}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10253075.000000: 100%|██████████| 10/10 [00:00<00:00, 213.18epoch/s]
# [I 2024-11-24 10:12:15,890] Trial 19 finished with value: 10253075.0 and parameters: {'lr': 4.7937209128327115e-05, 'batch_size': 30}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 304456304.000000: 100%|██████████| 10/10 [00:00<00:00, 138.97epoch/s]
# [I 2024-11-24 10:12:15,975] Trial 20 finished with value: 39662629.0 and parameters: {'lr': 0.0860458100994566, 'batch_size': 22}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 7815232.875000: 100%|██████████| 10/10 [00:00<00:00, 65.81epoch/s]
# [I 2024-11-24 10:12:16,141] Trial 21 finished with value: 7815232.875 and parameters: {'lr': 0.029631584557031642, 'batch_size': 9}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10076826.500000: 100%|██████████| 10/10 [00:00<00:00, 124.04epoch/s]
# [I 2024-11-24 10:12:16,235] Trial 22 finished with value: 9970105.25 and parameters: {'lr': 0.024631587367004625, 'batch_size': 15}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 9370364.000000: 100%|██████████| 10/10 [00:00<00:00, 214.13epoch/s]
# [I 2024-11-24 10:12:16,295] Trial 23 finished with value: 9040914.0 and parameters: {'lr': 0.007733586106785247, 'batch_size': 39}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 21538095.875000: 100%|██████████| 10/10 [00:00<00:00, 145.63epoch/s]
# [I 2024-11-24 10:12:16,377] Trial 24 finished with value: 5808878.515625 and parameters: {'lr': 0.03163880610207487, 'batch_size': 27}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 8988279.000000: 100%|██████████| 10/10 [00:00<00:00, 145.89epoch/s]
# [I 2024-11-24 10:12:16,460] Trial 25 finished with value: 5333699.75 and parameters: {'lr': 0.012312485410178632, 'batch_size': 27}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 9045183.000000: 100%|██████████| 10/10 [00:00<00:00, 131.92epoch/s]
# [I 2024-11-24 10:12:16,550] Trial 26 finished with value: 7918247.125 and parameters: {'lr': 0.001347650872242214, 'batch_size': 23}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 1297898624.000000: 100%|██████████| 10/10 [00:00<00:00, 227.48epoch/s]
# [I 2024-11-24 10:12:16,610] Trial 27 finished with value: 10253491.0 and parameters: {'lr': 0.06041029235134976, 'batch_size': 32}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10049575.000000: 100%|██████████| 10/10 [00:00<00:00, 237.86epoch/s]
# [I 2024-11-24 10:12:16,665] Trial 28 finished with value: 9367420.0 and parameters: {'lr': 0.004211731025865218, 'batch_size': 36}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10101131.750000: 100%|██████████| 10/10 [00:00<00:00, 129.10epoch/s]
# [I 2024-11-24 10:12:16,757] Trial 29 finished with value: 9121607.25 and parameters: {'lr': 0.0443161841550826, 'batch_size': 19}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10221347.000000: 100%|██████████| 10/10 [00:00<00:00, 139.37epoch/s]
# [I 2024-11-24 10:12:16,843] Trial 30 finished with value: 9575025.0 and parameters: {'lr': 0.01560980826454855, 'batch_size': 51}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10240089.000000: 100%|██████████| 10/10 [00:00<00:00, 203.28epoch/s]
# [I 2024-11-24 10:12:16,907] Trial 31 finished with value: 10020729.0 and parameters: {'lr': 0.007860235843467263, 'batch_size': 29}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 11743027.000000: 100%|██████████| 10/10 [00:00<00:00, 122.62epoch/s]
# [I 2024-11-24 10:12:17,002] Trial 32 finished with value: 6390304.125 and parameters: {'lr': 0.014177846429307831, 'batch_size': 25}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10857920.000000: 100%|██████████| 10/10 [00:00<00:00, 139.82epoch/s]
# [I 2024-11-24 10:12:17,090] Trial 33 finished with value: 7147984.5 and parameters: {'lr': 0.00010969521485463198, 'batch_size': 25}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10138912.000000: 100%|██████████| 10/10 [00:00<00:00, 126.61epoch/s]
# [I 2024-11-24 10:12:17,182] Trial 34 finished with value: 10138912.0 and parameters: {'lr': 0.0006577552401388744, 'batch_size': 34}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 9606476.000000: 100%|██████████| 10/10 [00:00<00:00, 138.65epoch/s]
# [I 2024-11-24 10:12:17,269] Trial 35 finished with value: 9600324.0 and parameters: {'lr': 0.01478604985579968, 'batch_size': 19}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10633908.000000: 100%|██████████| 10/10 [00:00<00:00, 222.82epoch/s]
# [I 2024-11-24 10:12:17,330] Trial 36 finished with value: 10253401.0 and parameters: {'lr': 0.04797511450889599, 'batch_size': 31}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 8204381.750000: 100%|██████████| 10/10 [00:00<00:00, 132.56epoch/s]
# [I 2024-11-24 10:12:17,420] Trial 37 finished with value: 7287636.0 and parameters: {'lr': 0.0035930311870538707, 'batch_size': 20}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 12595948.000000: 100%|██████████| 10/10 [00:00<00:00, 98.98epoch/s]
# [I 2024-11-24 10:12:17,535] Trial 38 finished with value: 7517594.630208333 and parameters: {'lr': 0.0008308714522019564, 'batch_size': 13}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 13940775.000000: 100%|██████████| 10/10 [00:00<00:00, 130.29epoch/s]
# [I 2024-11-24 10:12:17,625] Trial 39 finished with value: 6909279.0 and parameters: {'lr': 0.0002460434911495313, 'batch_size': 27}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10786140.000000: 100%|██████████| 10/10 [00:00<00:00, 133.38epoch/s]
# [I 2024-11-24 10:12:17,714] Trial 40 finished with value: 7403981.25 and parameters: {'lr': 0.006109741047045454, 'batch_size': 24}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 11776894.500000: 100%|██████████| 10/10 [00:00<00:00, 121.93epoch/s]
# [I 2024-11-24 10:12:17,811] Trial 41 finished with value: 5614228.46875 and parameters: {'lr': 0.01604094447830739, 'batch_size': 28}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 9429407.000000: 100%|██████████| 10/10 [00:00<00:00, 234.60epoch/s]
# [I 2024-11-24 10:12:17,866] Trial 42 finished with value: 9429407.0 and parameters: {'lr': 0.0019391768464607588, 'batch_size': 36}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 13487937.500000: 100%|██████████| 10/10 [00:00<00:00, 128.29epoch/s]
# [I 2024-11-24 10:12:17,959] Trial 43 finished with value: 9308209.75 and parameters: {'lr': 0.03506812776089241, 'batch_size': 27}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 8586614.000000: 100%|██████████| 10/10 [00:00<00:00, 136.31epoch/s]
# [I 2024-11-24 10:12:18,047] Trial 44 finished with value: 8586614.0 and parameters: {'lr': 0.016363515602877916, 'batch_size': 21}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 8027443.000000: 100%|██████████| 10/10 [00:00<00:00, 129.18epoch/s]
# [I 2024-11-24 10:12:18,165] Trial 45 finished with value: 8004268.5 and parameters: {'lr': 0.010916866201449998, 'batch_size': 17}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 26482132.000000: 100%|██████████| 10/10 [00:00<00:00, 133.27epoch/s]
# [I 2024-11-24 10:12:18,253] Trial 46 finished with value: 8618277.75 and parameters: {'lr': 0.0611520967754174, 'batch_size': 25}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 3389894144.000000: 100%|██████████| 10/10 [00:00<00:00, 222.52epoch/s]
# [I 2024-11-24 10:12:18,313] Trial 47 finished with value: 10253191.0 and parameters: {'lr': 0.09848270435983872, 'batch_size': 40}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10253088.000000: 100%|██████████| 10/10 [00:00<00:00, 209.58epoch/s]
# [I 2024-11-24 10:12:18,374] Trial 48 finished with value: 10252962.0 and parameters: {'lr': 3.907138796460836e-05, 'batch_size': 63}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 10228306.000000: 100%|██████████| 10/10 [00:00<00:00, 227.44epoch/s]
# [I 2024-11-24 10:12:18,433] Trial 49 finished with value: 10228306.0 and parameters: {'lr': 0.00042564170491417227, 'batch_size': 30}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 8118692.500000: 100%|██████████| 10/10 [00:00<00:00, 210.94epoch/s]
# [I 2024-11-24 10:12:18,494] Trial 50 finished with value: 8118692.5 and parameters: {'lr': 0.004627225793979803, 'batch_size': 36}. Best is trial 12 with value: 5311400.226318359.
# Epoch 10 | Loss: 4800214.906250: 100%|██████████| 10/10 [00:00<00:00, 129.28epoch/s]
# [I 2024-11-24 10:12:18,586] Trial 51 finished with value: 4800214.90625 and parameters: {'lr': 0.011257005595054985, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 8866131.250000: 100%|██████████| 10/10 [00:00<00:00, 124.90epoch/s]
# [I 2024-11-24 10:12:18,680] Trial 52 finished with value: 5530155.796875 and parameters: {'lr': 0.021093919617628406, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10144665.000000: 100%|██████████| 10/10 [00:00<00:00, 222.76epoch/s]
# [I 2024-11-24 10:12:18,740] Trial 53 finished with value: 9796874.0 and parameters: {'lr': 0.021489812415228005, 'batch_size': 34}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 23705306.250000: 100%|██████████| 10/10 [00:00<00:00, 95.04epoch/s]
# [I 2024-11-24 10:12:18,858] Trial 54 finished with value: 5331479.8671875 and parameters: {'lr': 0.0026852326982001904, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7756092.750000: 100%|██████████| 10/10 [00:00<00:00, 139.58epoch/s]
# [I 2024-11-24 10:12:18,944] Trial 55 finished with value: 5275078.5546875 and parameters: {'lr': 0.0029283538214214394, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 8775385.000000: 100%|██████████| 10/10 [00:00<00:00, 222.95epoch/s]
# [I 2024-11-24 10:12:19,002] Trial 56 finished with value: 8775385.0 and parameters: {'lr': 0.0029501277913959946, 'batch_size': 32}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9423563.000000: 100%|██████████| 10/10 [00:00<00:00, 213.61epoch/s]
# [I 2024-11-24 10:12:19,063] Trial 57 finished with value: 9423563.0 and parameters: {'lr': 0.0013233396528188695, 'batch_size': 43}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10414321.250000: 100%|██████████| 10/10 [00:00<00:00, 140.78epoch/s]
# [I 2024-11-24 10:12:19,148] Trial 58 finished with value: 8023049.5 and parameters: {'lr': 0.00205617547553108, 'batch_size': 22}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9419324.000000: 100%|██████████| 10/10 [00:00<00:00, 223.14epoch/s]
# [I 2024-11-24 10:12:19,209] Trial 59 finished with value: 9363849.0 and parameters: {'lr': 0.00770946376217541, 'batch_size': 29}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9168580.000000: 100%|██████████| 10/10 [00:00<00:00, 219.02epoch/s]
# [I 2024-11-24 10:12:19,269] Trial 60 finished with value: 9013356.0 and parameters: {'lr': 0.0058059242529557385, 'batch_size': 32}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10251708.000000: 100%|██████████| 10/10 [00:00<00:00, 211.35epoch/s]
# [I 2024-11-24 10:12:19,332] Trial 61 finished with value: 10067827.0 and parameters: {'lr': 0.009891779024098463, 'batch_size': 29}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7813161.000000: 100%|██████████| 10/10 [00:00<00:00, 135.70epoch/s]
# [I 2024-11-24 10:12:19,420] Trial 62 finished with value: 5536854.6171875 and parameters: {'lr': 0.002768940107502179, 'batch_size': 27}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 6998442.500000: 100%|██████████| 10/10 [00:00<00:00, 90.16epoch/s]
# [I 2024-11-24 10:12:19,554] Trial 63 finished with value: 6998442.5 and parameters: {'lr': 0.0020537171693413773, 'batch_size': 23}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9151768.000000: 100%|██████████| 10/10 [00:00<00:00, 117.47epoch/s]
# [I 2024-11-24 10:12:19,653] Trial 64 finished with value: 6114920.3125 and parameters: {'lr': 0.0029952484662221033, 'batch_size': 26}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10253288.000000: 100%|██████████| 10/10 [00:00<00:00, 217.76epoch/s]
# [I 2024-11-24 10:12:19,714] Trial 65 finished with value: 10253288.0 and parameters: {'lr': 1.0680121335602088e-05, 'batch_size': 34}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9991479.000000: 100%|██████████| 10/10 [00:00<00:00, 209.78epoch/s]
# [I 2024-11-24 10:12:19,776] Trial 66 finished with value: 9991479.0 and parameters: {'lr': 0.0008260461411102182, 'batch_size': 30}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10253154.000000: 100%|██████████| 10/10 [00:00<00:00, 223.72epoch/s]
# [I 2024-11-24 10:12:19,835] Trial 67 finished with value: 10253154.0 and parameters: {'lr': 1.8554157819958825e-05, 'batch_size': 38}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9397054.000000: 100%|██████████| 10/10 [00:00<00:00, 133.93epoch/s]
# [I 2024-11-24 10:12:19,923] Trial 68 finished with value: 9074486.75 and parameters: {'lr': 0.0011002498014865186, 'batch_size': 17}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 11796527.000000: 100%|██████████| 10/10 [00:00<00:00, 138.09epoch/s]
# [I 2024-11-24 10:12:20,011] Trial 69 finished with value: 6292976.125 and parameters: {'lr': 0.00043514287368661564, 'batch_size': 26}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 12426448.000000: 100%|██████████| 10/10 [00:00<00:00, 135.89epoch/s]
# [I 2024-11-24 10:12:20,100] Trial 70 finished with value: 8512973.5 and parameters: {'lr': 0.00010568176278486707, 'batch_size': 24}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 17710191.000000: 100%|██████████| 10/10 [00:00<00:00, 95.29epoch/s]
# [I 2024-11-24 10:12:20,218] Trial 71 finished with value: 6332184.46875 and parameters: {'lr': 0.019726554883728927, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 6810072.875000: 100%|██████████| 10/10 [00:00<00:00, 131.92epoch/s]
# [I 2024-11-24 10:12:20,308] Trial 72 finished with value: 4958373.23046875 and parameters: {'lr': 0.004306698800300588, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 8366226.000000: 100%|██████████| 10/10 [00:00<00:00, 224.24epoch/s]
# [I 2024-11-24 10:12:20,369] Trial 73 finished with value: 8366226.0 and parameters: {'lr': 0.0037980519480599597, 'batch_size': 31}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9383420.000000: 100%|██████████| 10/10 [00:00<00:00, 202.82epoch/s]
# [I 2024-11-24 10:12:20,433] Trial 74 finished with value: 9383420.0 and parameters: {'lr': 0.0022935715543770403, 'batch_size': 33}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7927723.000000: 100%|██████████| 10/10 [00:00<00:00, 129.44epoch/s]
# [I 2024-11-24 10:12:20,525] Trial 75 finished with value: 6179579.8125 and parameters: {'lr': 0.0015719365321228333, 'batch_size': 24}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10243769.000000: 100%|██████████| 10/10 [00:00<00:00, 116.29epoch/s]
# [I 2024-11-24 10:12:20,625] Trial 76 finished with value: 8424261.25 and parameters: {'lr': 0.005425178336427915, 'batch_size': 22}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 12238434.000000: 100%|██████████| 10/10 [00:00<00:00, 140.12epoch/s]
# [I 2024-11-24 10:12:20,712] Trial 77 finished with value: 5310606.08203125 and parameters: {'lr': 0.007277753363615861, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10106330.000000: 100%|██████████| 10/10 [00:00<00:00, 145.97epoch/s]
# [I 2024-11-24 10:12:20,794] Trial 78 finished with value: 8891729.5 and parameters: {'lr': 0.008559035027002814, 'batch_size': 20}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10217899.000000: 100%|██████████| 10/10 [00:00<00:00, 127.89epoch/s]
# [I 2024-11-24 10:12:20,888] Trial 79 finished with value: 9939725.0 and parameters: {'lr': 0.01148862504019896, 'batch_size': 31}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9201581.500000: 100%|██████████| 10/10 [00:00<00:00, 128.75epoch/s]
# [I 2024-11-24 10:12:20,979] Trial 80 finished with value: 5335513.33203125 and parameters: {'lr': 0.004611405224329507, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 12260346.500000: 100%|██████████| 10/10 [00:00<00:00, 115.59epoch/s]
# [I 2024-11-24 10:12:21,081] Trial 81 finished with value: 4828111.7265625 and parameters: {'lr': 0.006764993991341251, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7712063.750000: 100%|██████████| 10/10 [00:00<00:00, 136.84epoch/s]
# [I 2024-11-24 10:12:21,170] Trial 82 finished with value: 6648775.875 and parameters: {'lr': 0.004553515061762943, 'batch_size': 26}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9545732.000000: 100%|██████████| 10/10 [00:00<00:00, 211.70epoch/s]
# [I 2024-11-24 10:12:21,232] Trial 83 finished with value: 9545732.0 and parameters: {'lr': 0.0061501893757774225, 'batch_size': 54}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7707356.000000: 100%|██████████| 10/10 [00:00<00:00, 208.19epoch/s]
# [I 2024-11-24 10:12:21,295] Trial 84 finished with value: 7707356.0 and parameters: {'lr': 0.006925088052070255, 'batch_size': 29}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9692401.000000: 100%|██████████| 10/10 [00:00<00:00, 137.32epoch/s]
# [I 2024-11-24 10:12:21,382] Trial 85 finished with value: 7283265.75 and parameters: {'lr': 0.0035228988785788204, 'batch_size': 25}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10137516.000000: 100%|██████████| 10/10 [00:00<00:00, 125.00epoch/s]
# [I 2024-11-24 10:12:21,476] Trial 86 finished with value: 10116755.0 and parameters: {'lr': 0.011867434874531341, 'batch_size': 35}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 7968193.000000: 100%|██████████| 10/10 [00:00<00:00, 224.98epoch/s]
# [I 2024-11-24 10:12:21,535] Trial 87 finished with value: 7968193.0 and parameters: {'lr': 0.004848793885519157, 'batch_size': 31}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 5261993.081787: 100%|██████████| 10/10 [00:00<00:00, 139.00epoch/s]
# [I 2024-11-24 10:12:21,622] Trial 88 finished with value: 5261993.081787109 and parameters: {'lr': 0.009130347455667969, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9795578.000000: 100%|██████████| 10/10 [00:00<00:00, 200.29epoch/s]
# [I 2024-11-24 10:12:21,687] Trial 89 finished with value: 9795578.0 and parameters: {'lr': 0.008811505903100626, 'batch_size': 33}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10247274.000000: 100%|██████████| 10/10 [00:00<00:00, 211.39epoch/s]
# [I 2024-11-24 10:12:21,748] Trial 90 finished with value: 9552972.0 and parameters: {'lr': 0.006596846682002057, 'batch_size': 30}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 6255710.375000: 100%|██████████| 10/10 [00:00<00:00, 124.70epoch/s]
# [I 2024-11-24 10:12:21,844] Trial 91 finished with value: 5488428.25 and parameters: {'lr': 0.013220309989783612, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10359786.500000: 100%|██████████| 10/10 [00:00<00:00, 144.79epoch/s]
# [I 2024-11-24 10:12:21,927] Trial 92 finished with value: 7965618.125 and parameters: {'lr': 0.00420894821929066, 'batch_size': 23}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9702951.000000: 100%|██████████| 10/10 [00:00<00:00, 132.25epoch/s]
# [I 2024-11-24 10:12:22,049] Trial 93 finished with value: 6153853.3125 and parameters: {'lr': 0.0032313065969399803, 'batch_size': 27}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 6483251.000000: 100%|██████████| 10/10 [00:00<00:00, 134.88epoch/s]
# [I 2024-11-24 10:12:22,137] Trial 94 finished with value: 6061459.625 and parameters: {'lr': 0.002490426377197114, 'batch_size': 25}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 10248779.000000: 100%|██████████| 10/10 [00:00<00:00, 206.04epoch/s]
# [I 2024-11-24 10:12:22,200] Trial 95 finished with value: 10007286.0 and parameters: {'lr': 0.007790710644813082, 'batch_size': 30}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 6773704.625000: 100%|██████████| 10/10 [00:00<00:00, 140.57epoch/s]
# [I 2024-11-24 10:12:22,286] Trial 96 finished with value: 5301355.089874268 and parameters: {'lr': 0.0016277381189935818, 'batch_size': 28}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9009393.000000: 100%|██████████| 10/10 [00:00<00:00, 137.47epoch/s]
# [I 2024-11-24 10:12:22,374] Trial 97 finished with value: 9009393.0 and parameters: {'lr': 0.001716480604986332, 'batch_size': 21}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 9919326.000000: 100%|██████████| 10/10 [00:00<00:00, 217.75epoch/s]
# [I 2024-11-24 10:12:22,436] Trial 98 finished with value: 9684003.0 and parameters: {'lr': 0.02658194957858546, 'batch_size': 32}. Best is trial 51 with value: 4800214.90625.
# Epoch 10 | Loss: 8125443.250000: 100%|██████████| 10/10 [00:00<00:00, 95.92epoch/s]
# [I 2024-11-24 10:12:22,556] Trial 99 finished with value: 6138133.9375 and parameters: {'lr': 0.0011802528113116573, 'batch_size': 26}. Best is trial 51 with value: 4800214.90625.
# Best params: {'lr': 0.011257005595054985, 'batch_size': 28}
# Best loss: 4800214.90625

# %%
# Optunaのベイズ最適化
def objective(trial):
    return train_model(trial)

def perform_bayesian_optimization():
    # Optunaでハイパーパラメータ最適化のためのStudyを作成
    study = optuna.create_study(direction='minimize')
    
    # tqdmの進捗バーで試行回数を表示
    n_trials = 10
    progress_bar = tqdm(total=n_trials, desc="Bayesian Optimization Progress", unit="trial")
    
    def callback(study, trial):
        # 進捗バーを更新
        progress_bar.set_description(
            f"Trial {trial.number+1} | Best Loss: {study.best_value:.6f}")
        progress_bar.update(1)

    # 最適化の実行
    study.optimize(objective, n_trials=n_trials, callbacks=[callback])
    
    # 最適な結果を表示
    progress_bar.close()
    print("Best Hyperparameters:", study.best_params)
    print("Best Loss:", study.best_value)

    # 学習済みのモデルパラメータを保存
    best_params = study.best_params
    return best_params

if __name__ == '__main__':
    best_params = perform_bayesian_optimization()
    print("Optimization completed. Best parameters:", best_params)
# Out:
# [I 2024-11-24 10:12:22,561] A new study created in memory with name: no-name-056c2d18-aac3-4b0d-a77d-e073e252ff3e
# Bayesian Optimization Progress:   0%|          | 0/10 [00:00<?, ?trial/s]/var/folders/gj/4tb33ww155x9v49s74kyhlcc0000gn/T/ipykernel_29197/2780606731.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# Epoch 10 | Loss: 10342450.000000: 100%|██████████| 10/10 [00:00<00:00, 159.89epoch/s]
# [I 2024-11-24 10:12:22,638] Trial 0 finished with value: 9235854.0 and parameters: {'lr': 0.036028054973867664, 'batch_size': 53}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 10252966.000000: 100%|██████████| 10/10 [00:00<00:00, 197.74epoch/s]
# [I 2024-11-24 10:12:22,699] Trial 1 finished with value: 10252966.0 and parameters: {'lr': 2.1780708718462275e-05, 'batch_size': 45}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 10064064.000000: 100%|██████████| 10/10 [00:00<00:00, 215.45epoch/s]]
# [I 2024-11-24 10:12:22,755] Trial 2 finished with value: 9665062.0 and parameters: {'lr': 0.02095590966193384, 'batch_size': 33}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 10253396.000000: 100%|██████████| 10/10 [00:00<00:00, 192.51epoch/s]]
# [I 2024-11-24 10:12:22,818] Trial 3 finished with value: 10253376.0 and parameters: {'lr': 2.056713578025567e-05, 'batch_size': 37}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 10024578.000000: 100%|██████████| 10/10 [00:00<00:00, 206.98epoch/s]]
# [I 2024-11-24 10:12:22,877] Trial 4 finished with value: 9275494.0 and parameters: {'lr': 0.004709291474130712, 'batch_size': 31}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 10252418.000000: 100%|██████████| 10/10 [00:00<00:00, 194.08epoch/s]]
# [I 2024-11-24 10:12:22,939] Trial 5 finished with value: 10252418.0 and parameters: {'lr': 4.658124858317274e-05, 'batch_size': 36}. Best is trial 0 with value: 9235854.0.
# Epoch 10 | Loss: 8876972.333333: 100%|██████████| 10/10 [00:00<00:00, 104.35epoch/s]s]
# [I 2024-11-24 10:12:23,045] Trial 6 finished with value: 6945521.458333333 and parameters: {'lr': 0.0009952158350149069, 'batch_size': 14}. Best is trial 6 with value: 6945521.458333333.
# Epoch 10 | Loss: 8706833.500000: 100%|██████████| 10/10 [00:00<00:00, 93.35epoch/s]/s]
# [I 2024-11-24 10:12:23,164] Trial 7 finished with value: 7813602.0 and parameters: {'lr': 0.0009437210384365753, 'batch_size': 13}. Best is trial 6 with value: 6945521.458333333.
# Epoch 10 | Loss: 8698332.000000: 100%|██████████| 10/10 [00:00<00:00, 189.03epoch/s]s]
# [I 2024-11-24 10:12:23,227] Trial 8 finished with value: 8698332.0 and parameters: {'lr': 0.0033671294464917554, 'batch_size': 31}. Best is trial 6 with value: 6945521.458333333.
# Epoch 10 | Loss: 9410072.000000: 100%|██████████| 10/10 [00:00<00:00, 203.96epoch/s]s]
# [I 2024-11-24 10:12:23,288] Trial 9 finished with value: 9410072.0 and parameters: {'lr': 0.0015469060690682076, 'batch_size': 40}. Best is trial 6 with value: 6945521.458333333.
# Trial 10 | Best Loss: 6945521.458333: 100%|██████████| 10/10 [00:00<00:00, 13.80trial/s]
# Best Hyperparameters: {'lr': 0.0009952158350149069, 'batch_size': 14}
# Best Loss: 6945521.458333333
# Optimization completed. Best parameters: {'lr': 0.0009952158350149069, 'batch_size': 14}

# %%
def generate_output(input_data, model_path='results/best_model.pth'):
    model = SimpleModel()
    model.load_state_dict(torch.load(model_path, weights_only=True))
    model.eval()
    
    # 入力データをテンソルに変換し、生成
    input_tensor = torch.tensor(input_data, dtype=torch.float32)
    with torch.no_grad():
        output = model(input_tensor)
    return output.numpy()

# 生成AIテスト
if __name__ == '__main__':
    sample_input = [5, 32, 22]  # 例: 任意の3次元入力
    output = generate_output(sample_input)
    print(f"Generated Output: {output}")
# Out:
# Generated Output: [ -0.5067431 285.96954  ]
